# %%
from rdflib import Graph, URIRef

# %%
namespaces = {
    "http://www.w3.org/2000/10/swap/crypto#": "crypto",
    "http://www.w3.org/2000/10/swap/file#": "file",  
    "http://www.w3.org/2000/10/swap/graph#": "graph",    
    "http://www.w3.org/2000/10/swap/list#": "list",
    "http://www.w3.org/2000/10/swap/log#": "log",
    "http://www.w3.org/2000/10/swap/math#": "math",
    "http://www.w3.org/2000/10/swap/os#": "os",
    "http://www.w3.org/2007/rif-builtin-function#": "func",
    "http://www.w3.org/2007/rif-builtin-predicate#": "pred",    
    "http://www.w3.org/2000/10/swap/set#": "set" ,
    "http://www.w3.org/2000/10/swap/string#": "string",
    "http://www.w3.org/2000/10/swap/time#": "time",
    "http://eulersharp.sourceforge.net/2003/03swap/log-rules#": "e",
    "http://www.w3.org/1999/02/22-rdf-syntax-ns#": "rdf"
    
}
sources = [
    'https://github.com/sbp/cwm/raw/master/crypto.n3', 
    'https://github.com/sbp/cwm/raw/master/list.n3', 
    'https://github.com/sbp/cwm/raw/master/log.n3', 
    'https://github.com/sbp/cwm/raw/master/math.n3', 
    'https://github.com/sbp/cwm/raw/master/os.n3', 
    'https://github.com/sbp/cwm/raw/master/set.n3', 
    'https://github.com/sbp/cwm/raw/master/string.n3', 
    'https://github.com/sbp/cwm/raw/master/time.rdf', 
]

# %%
swap = Graph()

[swap.bind(prefix, URIRef(uri)) for uri, prefix in namespaces.items()]

for source in sources:
    format ='n3' if source.endswith('.n3') else 'xml'
    swap += Graph().parse(source, format=format)

# %%
query = """
    select ?s ?comment
    where {

        # ?s a <http://www.w3.org/1999/02/22-rdf-syntax-ns#Property>  ;
            rdfs:comment ?comment .
        filter(!isBlank(?s))
        #filter(strstarts(str(?s), "http://www.w3.org/2000/10/swap/log#"))
        
    }
"""
s = set(sorted([str(row.s) for row in swap.query(query)]))

# %%
s
# Out:
# {'http://www.w3.org/2000/10/swap/crypto#md5',
#  'http://www.w3.org/2000/10/swap/crypto#sha',
#  'http://www.w3.org/2000/10/swap/crypto#sign',
#  'http://www.w3.org/2000/10/swap/crypto#verify',
#  'http://www.w3.org/2000/10/swap/crypto#verifyBoolean',
#  'http://www.w3.org/2000/10/swap/list#append',
#  'http://www.w3.org/2000/10/swap/list#in',
#  'http://www.w3.org/2000/10/swap/list#last',
#  'http://www.w3.org/2000/10/swap/list#member',
#  'http://www.w3.org/2000/10/swap/log#conclusion',
#  'http://www.w3.org/2000/10/swap/log#conjunction',
#  'http://www.w3.org/2000/10/swap/log#content',
#  'http://www.w3.org/2000/10/swap/log#definitiveDocument',
#  'http://www.w3.org/2000/10/swap/log#definitiveService',
#  'http://www.w3.org/2000/10/swap/log#dtlit',
#  'http://www.w3.org/2000/10/swap/log#equalTo',
#  'http://www.w3.org/2000/10/swap/log#implies',
#  'http://www.w3.org/2000/10/swap/log#includes',
#  'http://www.w3.org/2000/10/swap/log#n3String',
#  'http://www.w3.org/2000/10/swap/log#notEqualTo',
#  'http://www.w3.org/2000/10/swap/log#notIncludes',
#  'http://www.w3.org/2000/10/swap/log#outputString',
#  'http://www.w3.org/2000/10/swap/log#parsedAsN3',
#  'http://www.w3.org/2000/10/swap/log#racine',
#  'http://www.w3.org/2000/10/swap/log#rawType',
#  'http://www.w3.org/2000/10/swap/log#rawUri',
#  'http://www.w3.org/2000/10/swap/log#semantics',
#  'http://www.w3.org/2000/10/swap/log#semanticsOrError',
#  'http://www.w3.org/2000/10/swap/log#uri',
#  'http://www.w3.org/2000/10/swap/math#absoluteValue',
#  'http://www.w3.org/2000/10/swap/math#atan2',
#  'http://www.w3.org/2000/10/swap/math#cos',
#  'http://www.w3.org/2000/10/swap/math#degrees',
#  'http://www.w3.org/2000/10/swap/math#difference',
#  'http://www.w3.org/2000/10/swap/math#exponentiation',
#  'http://www.w3.org/2000/10/swap/math#integerQuotient',
#  'http://www.w3.org/2000/10/swap/math#negation',
#  'http://www.w3.org/2000/10/swap/math#product',
#  'http://www.w3.org/2000/10/swap/math#quotient',
#  'http://www.w3.org/2000/10/swap/math#remainder',
#  'http://www.w3.org/2000/10/swap/math#rounded',
#  'http://www.w3.org/2000/10/swap/math#sin',
#  'http://www.w3.org/2000/10/swap/math#sinh',
#  'http://www.w3.org/2000/10/swap/math#sum',
#  'http://www.w3.org/2000/10/swap/math#tan',
#  'http://www.w3.org/2000/10/swap/math#tanh',
#  'http://www.w3.org/2000/10/swap/os#argv',
#  'http://www.w3.org/2000/10/swap/os#baseAbsolute',
#  'http://www.w3.org/2000/10/swap/os#baseRelative',
#  'http://www.w3.org/2000/10/swap/os#environ',
#  'http://www.w3.org/2000/10/swap/set#difference',
#  'http://www.w3.org/2000/10/swap/set#in',
#  'http://www.w3.org/2000/10/swap/set#intersection',
#  'http://www.w3.org/2000/10/swap/set#member',
#  'http://www.w3.org/2000/10/swap/set#symmetricDifference',
#  'http://www.w3.org/2000/10/swap/set#union',
#  'http://www.w3.org/2000/10/swap/string#contains',
#  'http://www.w3.org/2000/10/swap/string#containsIgnoringCase',
#  'http://www.w3.org/2000/10/swap/string#containsRoughly',
#  'http://www.w3.org/2000/10/swap/string#endsWith',
#  'http://www.w3.org/2000/10/swap/string#equalIgnoringCase',
#  'http://www.w3.org/2000/10/swap/string#greaterThan',
#  'http://www.w3.org/2000/10/swap/string#lessThan',
#  'http://www.w3.org/2000/10/swap/string#matches',
#  'http://www.w3.org/2000/10/swap/string#notContainsRoughly',
#  'http://www.w3.org/2000/10/swap/string#notEqualIgnoringCase',
#  'http://www.w3.org/2000/10/swap/string#notGreaterThan',
#  'http://www.w3.org/2000/10/swap/string#notLessThan',
#  'http://www.w3.org/2000/10/swap/string#notMatches',
#  'http://www.w3.org/2000/10/swap/string#replace',
#  'http://www.w3.org/2000/10/swap/string#scrape',
#  'http://www.w3.org/2000/10/swap/string#startsWith',
#  'http://www.w3.org/2000/10/swap/time#day',
#  'http://www.w3.org/2000/10/swap/time#dayOfWeek',
#  'http://www.w3.org/2000/10/swap/time#gmTime',
#  'http://www.w3.org/2000/10/swap/time#hour',
#  'http://www.w3.org/2000/10/swap/time#inSeconds',
#  'http://www.w3.org/2000/10/swap/time#localTime',
#  'http://www.w3.org/2000/10/swap/time#minute',
#  'http://www.w3.org/2000/10/swap/time#month',
#  'http://www.w3.org/2000/10/swap/time#second',
#  'http://www.w3.org/2000/10/swap/time#timeZone',
#  'http://www.w3.org/2000/10/swap/time#year'}

# %%
# JEN3
jen3 = Graph().parse('https://github.com/william-vw/jen3/raw/master/src/main/resources/etc/builtins/builtins_liberal.n3', format='n3')

# %%
query = """
    select ?s
    where {
        # ?s a ?type  .
        filter(!isBlank(?s))
        filter(!strstarts(str(?s), "http://www.w3.org/2000/10/swap/builtin#"))       
    }
"""
j = set(sorted([str(row.s) for row in jen3.query(query)]))

# %%
jen3.print()
# Out:
# @prefix : <http://www.w3.org/2000/10/swap/builtin#> .
# @prefix crypto: <http://www.w3.org/2000/10/swap/crypto#> .
# @prefix file: <http://www.w3.org/2000/10/swap/file#> .
# @prefix graph: <http://www.w3.org/2000/10/swap/graph#> .
# @prefix list: <http://www.w3.org/2000/10/swap/list#> .
# @prefix log: <http://www.w3.org/2000/10/swap/log#> .
# @prefix math: <http://www.w3.org/2000/10/swap/math#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix string: <http://www.w3.org/2000/10/swap/string#> .
# @prefix time1: <http://www.w3.org/2000/10/swap/time#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# :formulaAndFormula a :InputConstraintsDefinition ;
#     :checkFor [ :object [ :restricts :formula ] ;
#             :subject [ :restricts :formula ] ] ;
#     :domain [ :object [ :restricts :formulaOrVariable ] ;
#             :subject [ :restricts :formulaOrVariable ] ] ;
#     :trueFor [ a :Other ] .
#
# :maxOneVar a :VariableInputConstraint ;
#     :cardinality [ a :Max ;
#             rdf:value 1 ] .
#
# crypto:sha a :BuiltinDefinition ;
#     :inputConstraints :stringAndStringOrVariable .
#
# file:listFiles a :BuiltinDefinition ;
#     :inputConstraints :iriAndFormula ;
#     :isResourceIntensive true .
#
# graph:difference a :BuiltinDefinition ;
#     :inputConstraints [ :checkFor [ :object [ :restricts :formulaOrVariable ] ;
#                     :subject [ :listElementType [ :restricts :formula ] ;
#                             :size [ a :Exact ;
#                                     rdf:value 2 ] ] ] ;
#             :domain [ :object [ :restricts :formulaOrVariable ] ;
#                     :subject [ :oneOf ( [ :listElementType [ :restricts :formulaOrVariable ] ;
#                                         :size [ a :Exact ;
#                                                 rdf:value 2 ] ] [ :restricts :variable ] ) ] ] ;
#             :trueFor [ a :Other ] ] .
#
# graph:length a :BuiltinDefinition ;
#     :inputConstraints [ :checkFor [ :object [ :restricts :numberableOrVariable ] ;
#                     :subject [ :restricts :formula ] ] ;
#             :domain [ :object [ :restricts :numberableOrVariable ] ;
#                     :subject [ :restricts :formulaOrVariable ] ] ;
#             :trueFor [ a :Other ] ] .
#
# list:append a :BuiltinDefinition ;
#     :inputConstraints [ :checkFor [ :object [ :restricts :listOrVariable ] ;
#                     :subject [ :listElementType [ :restricts :list ] ] ] ;
#             :domain [ :object [ :restricts :listOrVariable ] ;
#                     :subject [ :restricts :listOrVariable ] ] ;
#             :trueFor [ a :Other ] ] .
#
# list:first a :BuiltinDefinition ;
#     :inputConstraints :listAndAny .
#
# list:in a :BuiltinDefinition ;
#     :inputConstraints :anyAndList .
#
# list:iterate a :BuiltinDefinition ;
#     :inputConstraints [ :checkFor [ :object [ :oneOf ( [ :listElements ( [ :restricts :intableOrVariable ] [ :restricts :any ] ) ] [ :restricts :variable ] ) ] ;
#                     :subject [ :restricts :list ] ] ;
#             :domain [ :object [ :oneOf ( [ :listElements ( [ :restricts :intableOrVariable ] [ :restricts :any ] ) ] [ :restricts :variable ] ) ] ;
#                     :subject [ :restricts :listOrVariable ] ] ;
#             :trueFor [ a :Other ] ] .
#
# list:last a :BuiltinDefinition ;
#     :inputConstraints :listAndAny .
#
# list:length a :BuiltinDefinition ;
#     :inputConstraints [ :checkFor [ :object [ :restricts :intableOrVariable ] ;
#                     :subject [ :restricts :list ] ] ;
#             :domain [ :object [ :restricts :intableOrVariable ] ;
#                     :subject [ :restricts :listOrVariable ] ] ;
#             :trueFor [ a :Other ] ] .
#
# list:member a :BuiltinDefinition ;
#     :inputConstraints :listAndAny .
#
# list:memberAt a :BuiltinDefinition ;
#     :inputConstraints [ :checkFor [ :object [ :restricts :any ] ;
#                     :subject [ :listElements ( [ :restricts :list ] [ :restricts :intable ] ) ] ] ;
#             :domain [ :object [ :restricts :any ] ;
#                     :subject [ :oneOf ( [ :listElements ( [ :restricts :listOrVariable ] [ :restricts :intableOrVariable ] ) ] [ :restricts :variable ] ) ] ] ;
#             :trueFor [ a :Other ] ] .
#
# list:remove a :BuiltinDefinition ;
#     :inputConstraints [ :checkFor [ :object [ :restricts :listOrVariable ] ;
#                     :subject [ :listElements ( [ :restricts :list ] [ :restricts :concrete ] ) ] ] ;
#             :domain [ :object [ :restricts :listOrVariable ] ;
#                     :subject [ :oneOf ( [ :listElements ( [ :restricts :listOrVariable ] [ :restricts :any ] ) ] [ :restricts :variable ] ) ] ] ;
#             :trueFor [ a :Other ] ] .
#
# list:removeAt a :BuiltinDefinition ;
#     :inputConstraints [ :checkFor [ :object [ :restricts :listOrVariable ] ;
#                     :subject [ :listElements ( [ :restricts :list ] [ :restricts :intable ] ) ] ] ;
#             :domain [ :object [ :restricts :listOrVariable ] ;
#                     :subject [ :oneOf ( [ :listElements ( [ :restricts :listOrVariable ] [ :restricts :intableOrVariable ] ) ] [ :restricts :variable ] ) ] ] ;
#             :trueFor [ a :Other ] ] .
#
# list:unique a :BuiltinDefinition ;
#     :inputConstraints [ :checkFor [ :object [ :restricts :listOrVariable ] ;
#                     :subject [ :restricts :concreteList ] ] ;
#             :domain [ :object [ :restricts :listOrVariable ] ;
#                     :subject [ :restricts :listOrVariable ] ] ;
#             :trueFor [ a :Other ] ] .
#
# log:bound a :BuiltinDefinition ;
#     :inputConstraints [ :checkFor [ :object [ :restricts :boolOrVariable ] ;
#                     :subject [ :restricts :any ] ] ;
#             :domain [ :object [ :restricts :boolOrVariable ] ;
#                     :subject [ :restricts :any ] ] ;
#             :trueFor [ a :Other ] ] .
#
# log:collectAllIn a :BuiltinDefinition ;
#     :inputConstraints [ :checkFor [ :object [ :restricts :any ] ;
#                     :subject [ :listElements ( [ :restricts :variable ] [ :restricts :formula ] [ :restricts :listOrVariable ] ) ] ] ;
#             :domain [ :object [ :restricts :any ] ;
#                     :subject [ :oneOf ( [ :listElements ( [ :restricts :variable ] [ :restricts :formulaOrVariable ] [ :restricts :listOrVariable ] ) ] [ :restricts :variable ] ) ] ] ;
#             :falseFor [ a :Other ] ;
#             :trueFor [ :object [ :restricts :any ] ;
#                     :subject [ :listElementType [ :restricts :variable ] ;
#                             :size [ a :Exact ;
#                                     rdf:value 3 ] ] ] ] ;
#     :isUniversal true .
#
# log:conclusion a :BuiltinDefinition ;
#     :inputConstraints :formulaAndFormulaOrVariable .
#
# log:conjunction a :BuiltinDefinition ;
#     :inputConstraints [ :checkFor [ :object [ :restricts :formulaOrVariable ] ;
#                     :subject [ :listElementType [ :restricts :formula ] ] ] ;
#             :domain [ :object [ :restricts :formulaOrVariable ] ;
#                     :subject [ :oneOf ( [ :listElementType [ :restricts :formulaOrVariable ] ] [ :restricts :variable ] ) ] ] ;
#             :trueFor [ a :Other ] ] .
#
# log:content a :BuiltinDefinition ;
#     :inputConstraints [ :checkFor [ :object [ :restricts :stringableOrVariable ] ;
#                     :subject [ :restricts :iri ] ] ;
#             :domain [ :object [ :restricts :stringableOrVariable ] ;
#                     :subject [ :restricts :iriOrVariable ] ] ;
#             :trueFor [ a :Other ] ] ;
#     :isResourceIntensive true .
#
# log:dtlit a :BuiltinDefinition ;
#     :inputConstraints [ :checkFor [ :oneOf ( [ :object [ :restricts :literalOrVariable ] ;
#                                 :subject [ :listElements ( [ :restricts :stringable ] [ :restricts :iri ] ) ] ] [ :object [ :restricts :literal ] ;
#                                 :subject [ :listElements ( [ :restricts :variable ] [ :restricts :variable ] ) ] ] [ :object [ :restricts :literal ] ;
#                                 :subject [ :restricts :variable ] ] ) ] ;
#             :domain [ :object [ :restricts :literalOrVariable ] ;
#                     :subject [ :oneOf ( [ :listElements ( [ :restricts :stringableOrVariable ] [ :restricts :iriOrVariable ] ) ] [ :restricts :variable ] ) ] ] ;
#             :trueFor [ a :Other ] ] .
#
# log:equalTo a :BuiltinDefinition ;
#     :inputConstraints :concreteAndConcreteOrVariable .
#
# log:forAllIn a :BuiltinDefinition ;
#     :inputConstraints [ :checkFor [ :object [ :restricts :formulaOrVariable ] ;
#                     :subject [ :listElementType [ :restricts :formula ] ;
#                             :size [ a :Exact ;
#                                     rdf:value 2 ] ] ] ;
#             :domain [ :object [ :restricts :formulaOrVariable ] ;
#                     :subject [ :oneOf ( [ :listElementType [ :restricts :formulaOrVariable ] ;
#                                         :size [ a :Exact ;
#                                                 rdf:value 2 ] ] [ :restricts :variable ] ) ] ] ;
#             :trueFor [ a :Other ] ] ;
#     :isUniversal true .
#
# log:includes a :BuiltinDefinition ;
#     :inputConstraints :formulaOrBaseAndFormula .
#
# log:inferences a :BuiltinDefinition ;
#     :inputConstraints :formulaAndFormulaOrVariable .
#
# log:langlit a :BuiltinDefinition ;
#     :inputConstraints [ :checkFor [ :oneOf ( [ :object [ :restricts :literalOrVariable ] ;
#                                 :subject [ :listElements ( [ :restricts :stringable ] [ :restricts :stringable ] ) ] ] [ :object [ :restricts :literal ] ;
#                                 :subject [ :listElements ( [ :restricts :variable ] [ :restricts :variable ] ) ] ] [ :object [ :restricts :literal ] ;
#                                 :subject [ :restricts :variable ] ] ) ] ;
#             :domain [ :object [ :restricts :literalOrVariable ] ;
#                     :subject [ :oneOf ( [ :listElements ( [ :restricts :stringableOrVariable ] [ :restricts :stringableOrVariable ] ) ] [ :restricts :variable ] ) ] ] ;
#             :trueFor [ a :Other ] ] .
#
# log:notEqualTo a :BuiltinDefinition ;
#     :inputConstraints :concreteAndConcrete .
#
# log:notIncludes a :BuiltinDefinition ;
#     :inputConstraints :formulaOrBaseAndFormula .
#
# log:outputString a :BuiltinDefinition ;
#     :inputConstraints :stringAndString ;
#     :instantiate false ;
#     :isStatic false .
#
# log:parsedAsN3 a :BuiltinDefinition ;
#     :inputConstraints [ :checkFor [ :oneOf ( [ :object [ :restricts :formulaOrVariable ] ;
#                                 :subject [ :restricts :string ] ] [ :object [ :restricts :formula ] ;
#                                 :subject [ :restricts :variable ] ] ) ] ;
#             :domain [ :object [ :restricts :formulaOrVariable ] ;
#                     :subject [ :restricts :stringOrVariable ] ] ;
#             :trueFor [ a :Other ] ] .
#
# log:rawType a :BuiltinDefinition ;
#     :inputConstraints [ :checkFor [ :object [ :restricts :iriOrVariable ] ;
#                     :subject [ :restricts :concrete ] ] ;
#             :domain [ :object [ :restricts :iriOrVariable ] ;
#                     :subject [ :restricts :any ] ] ;
#             :trueFor [ a :Other ] ] .
#
# log:semantics a :BuiltinDefinition ;
#     :inputConstraints :iriAndFormula ;
#     :isResourceIntensive true .
#
# log:semanticsOrError a :BuiltinDefinition ;
#     :inputConstraints [ :checkFor [ :object [ :oneOf ( [ :restricts :formula ] [ :restricts :literal ] [ :restricts :variable ] ) ] ;
#                     :subject [ :restricts :iri ] ] ;
#             :domain [ :object [ :oneOf ( [ :restricts :formula ] [ :restricts :literal ] [ :restricts :variable ] ) ] ;
#                     :subject [ :restricts :iriOrVariable ] ] ;
#             :trueFor [ a :Other ] ] ;
#     :isResourceIntensive true .
#
# log:skolem a :BuiltinDefinition ;
#     :inputConstraints [ :checkFor [ :object [ :restricts :any ] ;
#                     :subject [ :restricts :concreteList ] ] ;
#             :domain [ :object [ :restricts :any ] ;
#                     :subject [ :restricts :listOrVariable ] ] ;
#             :trueFor [ a :Other ] ] .
#
# log:test a :BuiltinDefinition ;
#     :inputConstraints [ :checkFor [ a :DomainMatch ] ;
#             :domain [ :oneOf ( [ :object [ :restricts :any ] ;
#                                 :subject [ :listElementType :exact3Vars ] ] [ :object [ :listElementType :exact3Vars ] ;
#                                 :subject [ :restricts :any ] ] ) ] ;
#             :trueFor [ a :Other ] ] .
#
# log:uri a :BuiltinDefinition ;
#     :inputConstraints [ :checkFor [ :oneOf ( [ :object [ :restricts :stringableOrVariable ] ;
#                                 :subject [ :restricts :iri ] ] [ :object [ :restricts :stringable ] ;
#                                 :subject [ :restricts :variable ] ] ) ] ;
#             :domain [ :object [ :restricts :stringableOrVariable ] ;
#                     :subject [ :restricts :iriOrVariable ] ] ;
#             :trueFor [ a :Other ] ] .
#
# log:uuid a :BuiltinDefinition ;
#     :inputConstraints [ :checkFor [ :object [ :restricts :stringOrVariable ] ;
#                     :subject [ :restricts :any ] ] ;
#             :domain [ :object [ :restricts :stringOrVariable ] ;
#                     :subject [ :restricts :any ] ] ;
#             :trueFor [ a :Other ] ] .
#
# math:absoluteValue a :BuiltinDefinition ;
#     :inputConstraints :numberAndNumberOrVariable .
#
# math:acos a :BuiltinDefinition ;
#     :inputConstraints :numberOrVariable .
#
# math:acosh a :BuiltinDefinition ;
#     :inputConstraints :numberOrVariable .
#
# math:asin a :BuiltinDefinition ;
#     :inputConstraints :numberOrVariable .
#
# math:asinh a :BuiltinDefinition ;
#     :inputConstraints :numberOrVariable .
#
# math:atan a :BuiltinDefinition ;
#     :inputConstraints :numberOrVariable .
#
# math:atanh a :BuiltinDefinition ;
#     :inputConstraints :numberOrVariable .
#
# math:ceiling a :BuiltinDefinition ;
#     :inputConstraints :numberAndNumberOrVariable .
#
# math:cos a :BuiltinDefinition ;
#     :inputConstraints :numberOrVariable .
#
# math:cosh a :BuiltinDefinition ;
#     :inputConstraints :numberOrVariable .
#
# math:degrees a :BuiltinDefinition ;
#     :inputConstraints :numberOrVariable .
#
# math:difference a :BuiltinDefinition ;
#     :inputConstraints :twoNumberListAndNumberOrVariable .
#
# math:equalTo a :BuiltinDefinition ;
#     :inputConstraints :concreteNumbers .
#
# math:exponentiation a :BuiltinDefinition ;
#     :inputConstraints :twoNumberListAndNumberOrVariable .
#
# math:floor a :BuiltinDefinition ;
#     :inputConstraints :numberAndNumberOrVariable .
#
# math:greaterThan a :BuiltinDefinition ;
#     :inputConstraints :unequalNumbers .
#
# math:lessThan a :BuiltinDefinition ;
#     :inputConstraints :unequalNumbers .
#
# math:logarithm a :BuiltinDefinition ;
#     :inputConstraints :twoNumberListAndNumberOrVariable .
#
# math:max a :BuiltinDefinition ;
#     :inputConstraints :concreteNumberListAndNumberOrVariable .
#
# math:min a :BuiltinDefinition ;
#     :inputConstraints :concreteNumberListAndNumberOrVariable .
#
# math:negation a :BuiltinDefinition ;
#     :inputConstraints :numberOrVariable .
#
# math:notEqualTo a :BuiltinDefinition ;
#     :inputConstraints :unequalNumbers .
#
# math:notGreaterThan a :BuiltinDefinition ;
#     :inputConstraints :concreteNumbers .
#
# math:notLessThan a :BuiltinDefinition ;
#     :inputConstraints :concreteNumbers .
#
# math:product a :BuiltinDefinition ;
#     :inputConstraints :concreteNumberListAndNumberOrVariable .
#
# math:quotient a :BuiltinDefinition ;
#     :inputConstraints :twoNumberListAndNumberOrVariable .
#
# math:radians a :BuiltinDefinition ;
#     :inputConstraints :numberOrVariable .
#
# math:remainder a :BuiltinDefinition ;
#     :inputConstraints :intIntListAndIntOrVariable .
#
# math:rounded a :BuiltinDefinition ;
#     :inputConstraints :numberAndNumberOrVariable .
#
# math:roundedTo a :BuiltinDefinition ;
#     :inputConstraints :numberIntListAndNumberOrVariable .
#
# math:sin a :BuiltinDefinition ;
#     :inputConstraints :numberOrVariable .
#
# math:sinh a :BuiltinDefinition ;
#     :inputConstraints :numberOrVariable .
#
# math:sum a :BuiltinDefinition ;
#     :inputConstraints :concreteNumberListAndNumberOrVariable .
#
# math:tan a :BuiltinDefinition ;
#     :inputConstraints :numberOrVariable .
#
# math:tanh a :BuiltinDefinition ;
#     :inputConstraints :numberOrVariable .
#
# string:capitalize a :BuiltinDefinition ;
#     :inputConstraints :stringAndStringOrVariable .
#
# string:concatenation a :BuiltinDefinition ;
#     :inputConstraints :concreteStringListAndStringOrVariable .
#
# string:contains a :BuiltinDefinition ;
#     :inputConstraints :stringAndString .
#
# string:containsIgnoringCase a :BuiltinDefinition ;
#     :inputConstraints :stringAndString .
#
# string:containsRoughly a :BuiltinDefinition ;
#     :inputConstraints :stringAndString .
#
# string:endsWith a :BuiltinDefinition ;
#     :inputConstraints :stringAndString .
#
# string:equalIgnoringCase a :BuiltinDefinition ;
#     :inputConstraints :stringAndString .
#
# string:format a :BuiltinDefinition ;
#     :inputConstraints :concreteStringListAndStringOrVariable .
#
# string:greaterThan a :BuiltinDefinition ;
#     :inputConstraints :stringAndString .
#
# string:join a :BuiltinDefinition ;
#     :inputConstraints [ :checkFor [ :object [ :restricts :stringableOrVariable ] ;
#                     :subject [ :listElements ( [ :restricts :stringableList ] [ :restricts :stringable ] ) ] ] ;
#             :domain [ :object [ :restricts :stringableOrVariable ] ;
#                     :subject [ :restricts :listOrVariable ] ] ;
#             :trueFor [ a :Other ] ] .
#
# string:length a :BuiltinDefinition ;
#     :inputConstraints [ :checkFor [ :object [ :restricts :intableOrVariable ] ;
#                     :subject [ :restricts :stringable ] ] ;
#             :domain [ :object [ :restricts :intableOrVariable ] ;
#                     :subject [ :restricts :stringableOrVariable ] ] ;
#             :trueFor [ a :Other ] ] .
#
# string:lessThan a :BuiltinDefinition ;
#     :inputConstraints :stringAndString .
#
# string:lowerCase a :BuiltinDefinition ;
#     :inputConstraints :stringAndStringOrVariable .
#
# string:matches a :BuiltinDefinition ;
#     :inputConstraints :stringAndRegex .
#
# string:notContainsRoughly a :BuiltinDefinition ;
#     :inputConstraints :stringAndString .
#
# string:notEqualIgnoringCase a :BuiltinDefinition ;
#     :inputConstraints :stringAndString .
#
# string:notGreaterThan a :BuiltinDefinition ;
#     :inputConstraints :stringAndString .
#
# string:notLessThan a :BuiltinDefinition ;
#     :inputConstraints :stringAndString .
#
# string:notMatches a :BuiltinDefinition ;
#     :inputConstraints :stringAndRegex .
#
# string:replace a :BuiltinDefinition ;
#     :inputConstraints [ :checkFor [ :object [ :restricts :stringableOrVariable ] ;
#                     :subject [ :listElements ( [ :restricts :stringable ] [ :restricts :regex ] [ :restricts :stringable ] ) ] ] ;
#             :domain [ :object [ :restricts :stringableOrVariable ] ;
#                     :subject [ :oneOf ( [ :listElements ( [ :restricts :stringableOrVariable ] [ :restricts :regexOrVariable ] [ :restricts :stringableOrVariable ] ) ] [ :restricts :variable ] ) ] ] ;
#             :trueFor [ a :Other ] ] .
#
# string:scrape a :BuiltinDefinition ;
#     :inputConstraints [ :checkFor [ :object [ :restricts :stringableOrVariable ] ;
#                     :subject [ :listElements ( [ :restricts :stringable ] [ :restricts :regex ] ) ] ] ;
#             :domain [ :object [ :restricts :stringableOrVariable ] ;
#                     :subject [ :oneOf ( [ :listElements ( [ :restricts :stringableOrVariable ] [ :restricts :regexOrVariable ] ) ] [ :restricts :variable ] ) ] ] ;
#             :trueFor [ a :Other ] ] .
#
# string:scrapeAll a :BuiltinDefinition ;
#     :inputConstraints [ :checkFor [ :object [ :restricts :listOrVariable ] ;
#                     :subject [ :listElements ( [ :restricts :stringable ] [ :restricts :regex ] ) ] ] ;
#             :domain [ :object [ :restricts :listOrVariable ] ;
#                     :subject [ :oneOf ( [ :listElements ( [ :restricts :stringableOrVariable ] [ :restricts :regexOrVariable ] ) ] [ :restricts :variable ] ) ] ] ;
#             :trueFor [ a :Other ] ] .
#
# string:startsWith a :BuiltinDefinition ;
#     :inputConstraints :stringAndString .
#
# string:substring a :BuiltinDefinition ;
#     :inputConstraints [ :checkFor [ :object [ :restricts :stringableOrVariable ] ;
#                     :subject [ :listElements ( [ :restricts :stringable ] [ :restricts :intable ] [ :restricts :intableOrVariable ] ) ] ] ;
#             :domain [ :object [ :restricts :stringableOrVariable ] ;
#                     :subject [ :oneOf ( [ :listElements ( [ :restricts :stringableOrVariable ] [ :restricts :intableOrVariable ] [ :restricts :intableOrVariable ] ) ] [ :restricts :variable ] ) ] ] ;
#             :trueFor [ a :Other ] ] .
#
# string:upperCase a :BuiltinDefinition ;
#     :inputConstraints :stringAndStringOrVariable .
#
# time1:currentTime a :BuiltinDefinition ;
#     :inputConstraints [ :checkFor [ a :DomainMatch ] ;
#             :domain [ :object [ :oneOf ( [ :datatype xsd:dateTime ] [ :restricts :variable ] ) ] ;
#                     :subject [ :restricts :baseIri ] ] ] .
#
# time1:day a :BuiltinDefinition ;
#     :inputConstraints :dateAndIntableOrVariable .
#
# time1:dayOfWeek a :BuiltinDefinition ;
#     :inputConstraints :dateAndIntableOrVariable .
#
# time1:hour a :BuiltinDefinition ;
#     :inputConstraints :timeAndIntableOrVariable .
#
# time1:inSeconds a :BuiltinDefinition ;
#     :inputConstraints [ :checkFor [ :oneOf ( [ :object [ :restricts :intableOrVariable ] ;
#                                 :subject [ :datatype xsd:dateTime ] ] [ :object [ :restricts :intable ] ;
#                                 :subject [ :restricts :variable ] ] ) ] ;
#             :domain [ :object [ :restricts :intableOrVariable ] ;
#                     :subject [ :oneOf ( [ :datatype xsd:dateTime ] [ :restricts :variable ] ) ] ] ;
#             :trueFor [ a :Other ] ] .
#
# time1:minute a :BuiltinDefinition ;
#     :inputConstraints :timeAndIntableOrVariable .
#
# time1:month a :BuiltinDefinition ;
#     :inputConstraints :dateAndIntableOrVariable .
#
# time1:second a :BuiltinDefinition ;
#     :inputConstraints :timeAndIntableOrVariable .
#
# time1:timeZone a :BuiltinDefinition ;
#     :inputConstraints :dateOrTimeAndIntableOrVariable .
#
# time1:year a :BuiltinDefinition ;
#     :inputConstraints :dateAndIntableOrVariable .
#
# :anyAndList a :InputConstraints ;
#     :checkFor [ :object [ :restricts :list ] ;
#             :subject [ :restricts :any ] ] ;
#     :domain [ :object [ :restricts :listOrVariable ] ;
#             :subject [ :restricts :any ] ] ;
#     :trueFor [ a :Other ] .
#
# :concreteAndConcrete a :InputConstraintsDefinition ;
#     :checkFor [ :object [ :restricts :concrete ] ;
#             :subject [ :restricts :concrete ] ] ;
#     :domain [ :object [ :restricts :any ] ;
#             :subject [ :restricts :any ] ] ;
#     :trueFor [ a :Other ] .
#
# :concreteAndConcreteOrVariable a :InputConstraintsDefinition ;
#     :checkFor [ :oneOf ( [ :object [ :restricts :any ] ;
#                         :subject [ :restricts :concrete ] ] [ :object [ :restricts :concrete ] ;
#                         :subject [ :restricts :any ] ] ) ] ;
#     :domain [ :object [ :restricts :any ] ;
#             :subject [ :restricts :any ] ] ;
#     :trueFor [ a :Other ] .
#
# :dateOrTimeAndIntableOrVariable a :InputConstraintsDefinition ;
#     :checkFor [ :object [ :restricts :intableOrVariable ] ;
#             :subject [ :restricts :dateOrTime ] ] ;
#     :domain [ :object [ :restricts :intableOrVariable ] ;
#             :subject [ :oneOf ( [ :restricts :dateOrTime ] [ :restricts :variable ] ) ] ] ;
#     :trueFor [ a :Other ] .
#
# :exactOneVar a :VariableInputConstraint ;
#     :cardinality [ a :Exact ;
#             rdf:value 1 ] .
#
# :intIntListAndIntOrVariable a :InputConstraintsDefinition ;
#     :checkFor [ :object :intableOrVariable ;
#             :subject [ :listElements ( :intable :intable ) ] ] ;
#     :domain [ :object :intableOrVariable ;
#             :subject [ :oneOf ( [ :listElements ( :intableOrVariable :intableOrVariable ) ] [ :restricts :variable ] ) ] ] ;
#     :trueFor [ a :Other ] .
#
# :numberIntListAndNumberOrVariable a :InputConstraintsDefinition ;
#     :checkFor [ :object :numberableOrVariable ;
#             :subject [ :listElements ( :numberable :intable ) ] ] ;
#     :domain [ :object :numberableOrVariable ;
#             :subject [ :oneOf ( [ :listElements ( :numberableOrVariable :intableOrVariable ) ] [ :restricts :variable ] ) ] ] ;
#     :trueFor [ a :Other ] .
#
# :numberableOrVariableList a :ListInputConstraint ;
#     :listElementType :numberableOrVariable .
#
# :stringableOrVariableList a :ListInputConstraint ;
#     :listElementType :stringableOrVariable .
#
# :boolOrVariable :oneOf ( [ :datatype xsd:boolean ] :variable ) .
#
# :concreteList a :ListInputConstraint ;
#     :listElementType :concrete .
#
# :concreteStringListAndStringOrVariable a :InputConstraintsDefinition ;
#     :checkFor [ :object [ :restricts :stringableOrVariable ] ;
#             :subject [ :restricts :stringableList ] ] ;
#     :domain [ :object [ :restricts :stringableOrVariable ] ;
#             :subject [ :oneOf ( [ :restricts :stringableOrVariableList ] [ :restricts :variable ] ) ] ] ;
#     :trueFor [ a :Other ] .
#
# :dateOrTime :oneOf ( [ :datatype xsd:dateTime ] [ :datatype xsd:date ] [ :datatype xsd:time ] ) .
#
# :dateType :oneOf ( [ :datatype xsd:dateTime ] [ :datatype xsd:date ] ) .
#
# :exact3Vars a :VariableInputConstraint ;
#     :cardinality [ a :Exact ;
#             rdf:value 3 ] .
#
# :formulaAndFormulaOrVariable a :InputConstraints ;
#     :checkFor [ :object [ :restricts :formulaOrVariable ] ;
#             :subject [ :restricts :formula ] ] ;
#     :domain [ :object [ :restricts :formulaOrVariable ] ;
#             :subject [ :restricts :formulaOrVariable ] ] ;
#     :trueFor [ a :Other ] .
#
# :formulaOrBaseAndFormula a :InputConstraintsDefinition ;
#     :checkFor [ :object [ :restricts :formula ] ;
#             :subject [ :oneOf ( [ :restricts :formula ] [ :restricts :baseIri ] ) ] ] ;
#     :domain [ :object [ :restricts :formulaOrVariable ] ;
#             :subject [ :oneOf ( [ :restricts :formula ] [ :restricts :variable ] [ :restricts :baseIri ] ) ] ] ;
#     :trueFor [ a :Other ] .
#
# :iriAndFormula a :InputConstraints ;
#     :checkFor [ :object [ :restricts :formulaOrVariable ] ;
#             :subject [ :restricts :iri ] ] ;
#     :domain [ :object [ :restricts :formulaOrVariable ] ;
#             :subject [ :restricts :iriOrVariable ] ] ;
#     :trueFor [ a :Other ] .
#
# :numberableList a :ListInputConstraint ;
#     :listElementType :numberable .
#
# :string a :StringInputConstraint .
#
# :stringAndRegex a :InputConstraintsDefinition ;
#     :checkFor [ :object [ :restricts :regex ] ;
#             :subject [ :restricts :stringable ] ] ;
#     :domain [ :object [ :restricts :regexOrVariable ] ;
#             :subject [ :restricts :stringableOrVariable ] ] ;
#     :trueFor [ a :Other ] .
#
# :stringableList a :ListInputConstraint ;
#     :listElementType :stringable .
#
# :timeType :oneOf ( [ :datatype xsd:dateTime ] [ :datatype xsd:time ] ) .
#
# :baseIri a :BaseIriInputConstraint .
#
# :concreteNumbers a :InputConstraintsDefinition ;
#     :checkFor [ :object [ :restricts :numberable ] ;
#             :subject [ :restricts :numberable ] ] ;
#     :domain [ :object [ :restricts :numberableOrVariable ] ;
#             :subject [ :restricts :numberableOrVariable ] ] ;
#     :trueFor [ a :Other ] .
#
# :listAndAny a :InputConstraints ;
#     :checkFor [ :object [ :restricts :any ] ;
#             :subject [ :restricts :list ] ] ;
#     :domain [ :object [ :restricts :any ] ;
#             :subject [ :restricts :listOrVariable ] ] ;
#     :trueFor [ a :Other ] .
#
# :stringOrVariable :oneOf ( :string :variable ) .
#
# :timeAndIntableOrVariable a :InputConstraintsDefinition ;
#     :checkFor [ :object [ :restricts :intableOrVariable ] ;
#             :subject [ :restricts :timeType ] ] ;
#     :domain [ :object [ :restricts :intableOrVariable ] ;
#             :subject [ :oneOf ( [ :restricts :timeType ] [ :restricts :variable ] ) ] ] ;
#     :trueFor [ a :Other ] .
#
# :unequalNumbers a :InputConstraintsDefinition ;
#     :checkFor [ :object [ :restricts :numberable ] ;
#             :subject [ :restricts :numberable ] ] ;
#     :domain [ :object [ :restricts :numberableOrVariable ] ;
#             :subject [ :restricts :numberableOrVariable ] ] ;
#     :falseFor [ :subjectObject [ :restricts :exactOneVar ] ] ;
#     :trueFor [ a :Other ] .
#
# :concreteNumberListAndNumberOrVariable a :InputConstraintsDefinition ;
#     :checkFor [ :object [ :restricts :numberableOrVariable ] ;
#             :subject [ :restricts :numberableList ] ] ;
#     :domain [ :object [ :restricts :numberableOrVariable ] ;
#             :subject [ :oneOf ( [ :restricts :numberableOrVariableList ] [ :restricts :variable ] ) ] ] ;
#     :trueFor [ a :Other ] .
#
# :dateAndIntableOrVariable a :InputConstraintsDefinition ;
#     :checkFor [ :object [ :restricts :intableOrVariable ] ;
#             :subject [ :restricts :dateType ] ] ;
#     :domain [ :object [ :restricts :intableOrVariable ] ;
#             :subject [ :oneOf ( [ :restricts :dateType ] [ :restricts :variable ] ) ] ] ;
#     :trueFor [ a :Other ] .
#
# :literalOrVariable :oneOf ( :literal :variable ) .
#
# :numberAndNumberOrVariable a :InputConstraintsDefinition ;
#     :checkFor [ :object [ :restricts :numberableOrVariable ] ;
#             :subject [ :restricts :numberable ] ] ;
#     :domain [ :object [ :restricts :numberableOrVariable ] ;
#             :subject [ :restricts :numberableOrVariable ] ] ;
#     :trueFor [ a :Other ] .
#
# :regexOrVariable :oneOf ( :regex :variable ) .
#
# :stringAndStringOrVariable a :InputConstraintsDefinition ;
#     :checkFor [ :object [ :restricts :stringableOrVariable ] ;
#             :subject [ :restricts :stringable ] ] ;
#     :domain [ :object [ :restricts :stringableOrVariable ] ;
#             :subject [ :restricts :stringableOrVariable ] ] ;
#     :trueFor [ a :Other ] .
#
# :twoNumberListAndNumberOrVariable a :InputConstraintsDefinition ;
#     :checkFor [ :object [ :restricts :numberableOrVariable ] ;
#             :subject [ :restricts :numberableList ] ] ;
#     :domain [ :object [ :restricts :numberableOrVariable ] ;
#             :subject [ :oneOf ( [ :listElementType [ :restricts :numberableOrVariable ] ;
#                                 :size [ a :Exact ;
#                                         rdf:value 2 ] ] [ :restricts :variable ] ) ] ] ;
#     :trueFor [ a :Other ] .
#
# :regex a :RegexInputConstraint .
#
# :iri a :IriInputConstraint .
#
# :concrete a :ConcreteInputConstraint .
#
# :iriOrVariable :oneOf ( :iri :variable ) .
#
# :literal a :LiteralInputConstraint .
#
# :intable a :IntableInputConstraint .
#
# :list a :ListInputConstraint .
#
# :numberable a :NumberableInputConstraint .
#
# :stringAndString a :InputConstraintsDefinition ;
#     :checkFor [ :object [ :restricts :stringable ] ;
#             :subject [ :restricts :stringable ] ] ;
#     :domain [ :object [ :restricts :stringableOrVariable ] ;
#             :subject [ :restricts :stringableOrVariable ] ] ;
#     :trueFor [ a :Other ] .
#
# :formula a :FormulaInputConstraint .
#
# :numberOrVariable a :InputConstraintsDefinition ;
#     :checkFor [ :oneOf ( [ :object [ :restricts :numberableOrVariable ] ;
#                         :subject [ :restricts :numberable ] ] [ :object [ :restricts :numberable ] ;
#                         :subject [ :restricts :numberableOrVariable ] ] ) ] ;
#     :domain [ :object [ :restricts :numberableOrVariable ] ;
#             :subject [ :restricts :numberableOrVariable ] ] ;
#     :trueFor [ a :Other ] .
#
# :stringable a :StringableInputConstraint .
#
# :formulaOrVariable :oneOf ( :formula :variable ) .
#
# :numberableOrVariable :oneOf ( :numberable :variable ) .
#
# :listOrVariable :oneOf ( :list :variable ) .
#
# :intableOrVariable :oneOf ( :intable :variable ) .
#
# :any a :AnyInputConstraint .
#
# :stringableOrVariable :oneOf ( :stringable :variable ) .
#
# :variable a :VariableInputConstraint .
#
# [] a :ResolveJavaClass ;
#     :javaPackage "org.apache.jena.reasoner.rulesys.builtins.n3" .

# %%
# EYE builtins
eye = Graph().parse('https://github.com/josd/eye/raw/master/eye-builtins.n3', format='n3')

# %%
query = """
    select ?s
    where {
        # ?s a ?type  .
        #filter(strstarts(str(?s), "http://www.w3.org/2000/10/swap/log#"))   
    }

"""
e = set(sorted([str(row.s) for row in eye.query(query)]))

# %%
all = set.union(s, j, e)

# %%
import numpy as np
import pandas as pd
dfall = pd.DataFrame(all, columns=['all']).sort_values('all').reset_index(drop=True)
dfswap = pd.DataFrame(s, columns=['swap']).sort_values('swap').reset_index(drop=True)
dfjen3 = pd.DataFrame(j, columns=['jen3']).sort_values('jen3').reset_index(drop=True)
dfeye = pd.DataFrame(e, columns=['eye']).sort_values('eye').reset_index(drop=True)

# create matrix of dataframe intersections
df = pd.concat([dfall, dfswap, dfjen3, dfeye], axis=1, ignore_index=True, sort=True)
df.columns = ['function', 'swap', 'jen3', 'eye']

df1 = pd.merge(dfall, dfswap, how='left', left_on='all', right_on='swap').fillna('')
df2 = pd.merge(df1, dfjen3, how='left', left_on='all', right_on='jen3').fillna('')
df3 = pd.merge(df2, dfeye, how='left', left_on='all', right_on='eye').fillna('')
df3['swap'] = df3['swap'].apply(lambda x: 'x' if x else '')
df3['jen3'] = df3['jen3'].apply(lambda x: 'x' if x else '')
df3['eye'] = df3['eye'].apply(lambda x: 'x' if x else '')
df3['prefix'] = df3['all'].apply(lambda x: namespaces[f"{x.split('#')[0]}#"])
df3['all'] = df3['all'].apply(lambda x: x.split('#')[1])
final = df3.rename(columns={'all': 'function'}).sort_values(['prefix', 'function']).reset_index(drop=True)
final.to_csv('function-comparison.csv', index=False)

# %%
final
# Out:
#      function swap jen3 eye  prefix
# 0         md5    x        x  crypto
# 1         sha    x    x   x  crypto
# 2      sha256             x  crypto
# 3      sha512             x  crypto
# 4        sign    x           crypto
# ..        ...  ...  ...  ..     ...
# 332    minute    x    x        time
# 333     month    x    x   x    time
# 334    second    x    x        time
# 335  timeZone    x    x        time
# 336      year    x    x   x    time
#
# [337 rows x 5 columns]
