# %%
from rdflib import Graph, URIRef

# %%
n3e_uri ='https://github.com/william-vw/n3-editor-js/raw/master/tests/'
eye_uri = 'https://github.com/phochste/Notation3-By-Example/raw/main/list/'

sources = [
            f"{n3e_uri}explain_copd1.n3", 
            f"{n3e_uri}explain_diabetes1.n3",             
            f"{n3e_uri}explain_diabetes2.n3",             
            # f"{n3e_uri}explain_diabetes3.n3",  # KEY ERROR LOG           
            f"{n3e_uri}explain_diabetes4.n3",                                                 
            f"{n3e_uri}explain_lldm.n3",                                                      
            f"{n3e_uri}explain_medic.n3",                                                                  
            f"{n3e_uri}explain_witch.n3",                                                                  
           ]

# %%
g = Graph()

for source in sources:
    g += Graph().parse(source, format='n3')
    
g.print()
# Out:
# @prefix ns1: <http://www.w3.org/2000/10/swap/log#> .
# @prefix ns2: <http://eulersharp.sourceforge.net/2006/02swap/med#> .
# @prefix ns3: <http://josd.github.io/eye/reasoning/witch#> .
# @prefix ns4: <http://purl.obolibrary.org/obo/DDO.owl#> .
# @prefix ns5: <http://niche.cs.dal.ca/codegen.owl#> .
# @prefix ns6: <http://www.agfa.com/w3c/2002/10/medicad/op/lldmP#> .
# @prefix ns7: <http://wvw.org/copd#> .
# @prefix ns8: <http://eulersharp.sourceforge.net/2003/03swap/fl-rules#> .
# @prefix ns9: <https://bioportal.bioontology.org/ontologies/DMTO.owl#> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# ns2:aspirinHighDose ns2:excludedFor ns2:ActivePepticUlcerDisease,
#         ns2:AllergyForAspirin ;
#     ns2:prescribedFor ns2:Fever .
#
# ns3:DUCK a ns3:FLOATS ;
#     ns3:SAMEWEIGHT ns3:GIRL .
#
# ...
