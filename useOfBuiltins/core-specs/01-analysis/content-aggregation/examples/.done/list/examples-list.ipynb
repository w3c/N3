# %%
from rdflib import Graph, URIRef

# %%
w3c_uri ='https://raw.githubusercontent.com/w3c/N3/master/tests/N3Tests/cwm_list/'

phochste_uri = 'https://github.com/phochste/Notation3-By-Example/raw/main/list/'

sources = [
            # f"{w3c_uri}append.n3",
            # f"{w3c_uri}construct.n3",
            # f"{w3c_uri}first.n3"
            # f"{w3c_uri}last.n3",
            # f"{w3c_uri}unify1.n3",
            # f"{w3c_uri}unify2.n3",
            # f"{w3c_uri}unify3.n3",
            # f"{w3c_uri}unify4.n3",
            # f"{w3c_uri}unify5.n3",      
            f"{phochste_uri}append.n3",                               
            f"{phochste_uri}first.n3",               
            f"{phochste_uri}firstRest.n3",      
            f"{phochste_uri}in.n3",                                               
            f"{phochste_uri}iterate.n3",   
            f"{phochste_uri}last.n3",                                                   
            f"{phochste_uri}length.n3",                           
            f"{phochste_uri}map.n3",    
            f"{phochste_uri}member.n3",                                                              
            f"{phochste_uri}memberAt.n3",
            f"{phochste_uri}remove.n3",            
            f"{phochste_uri}removeAt.n3",                        
            f"{phochste_uri}removeDuplicates.n3",    
            "eye-list-examples.n3",
            "eye-rdf-examples.n3",          
           ]

# %%
g = Graph()

for source in sources:
    g += Graph().parse(source, format='n3')
    
g.print()
# Out:
# @prefix ns1: <http://www.w3.org/2000/10/swap/log#> .
# @prefix ns2: <urn:example:> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# {_:_:Formula103} ns1:implies {_:_:Formula104} .
#
# {_:_:Formula176} ns1:implies {_:_:Formula177} .
#
# ns2:Let ns2:param ( 1 2 3 ),
#         ( ( 1 ) ( "cat" ) ( 2 3 ) ),
#         ( 1 2 3 ),
#         ( "Huey" "Dewey" "Louie" ),
#         ( 1 2 3 ),
#         ( ( 1 2 ) ( 2 2 ) ( 3 2 ) ( 4 2 ) ),
#         ( "Huey" "Dewey" "Louie" ),
#         ( "Huey" "Dewey" "Louie" ),
#         ( "Huey" "Dewey" "Louie" ),
#         ( "Huey" "Dewey" "Dewey" "Louie" ),
#         ( 1 2 3 ),
#         ( "Huey" "Dewey" "Dewey" "Louie" ) ;
#     ns2:param1 "cat" ;
#     ns2:param2 ( 1 "cat" 2 3 ) .
#
# {_:_:Formula100} ns1:implies {_:_:Formula101} .
#
# {_:_:Formula105} ns1:implies {_:_:Formula106} .
#
# {_:_:Formula108} ns1:implies {_:_:Formula109} .
#
# ...
