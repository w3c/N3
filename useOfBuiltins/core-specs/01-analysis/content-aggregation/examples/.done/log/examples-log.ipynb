# %%
from rdflib import Graph, URIRef

# %%
w3c_uri ='https://github.com/w3c/N3/raw/master/tests/N3Tests/cwm_list/'
phochste_uri = 'https://raw.githubusercontent.com/phochste/Notation3-By-Example/main/log/'

sources = [
           f"{phochste_uri}becomes.n3",
           f"{phochste_uri}bound.n3",
           f"{phochste_uri}collectAllIn.n3",
           f"{phochste_uri}conclusion.n3",
           f"{phochste_uri}conjunction.n3",
           f"{phochste_uri}content.n3",
           f"{phochste_uri}dtlit.n3",
           f"{phochste_uri}equalTo.n3",
           f"{phochste_uri}forAllIn.n3",
           f"{phochste_uri}implies.n3",
           f"{phochste_uri}includes.n3",
           f"{phochste_uri}inferences.n3",
           f"{phochste_uri}langlit.n3",
           f"{phochste_uri}localN3String.n3",
           f"{phochste_uri}localName.n3",
           f"{phochste_uri}n3String.n3",
           f"{phochste_uri}namespace.n3",
           f"{phochste_uri}notEqualTo.n3",
           f"{phochste_uri}notIncludes.n3",
           f"{phochste_uri}outputString.n3",
           f"{phochste_uri}parsedAsN3.n3",
           f"{phochste_uri}racine.n3",
         #   f"{phochste_uri}rawType.n3",  # BAD SYNTAX
           f"{phochste_uri}repeat.n3",
           f"{phochste_uri}semantics.n3",
           f"{phochste_uri}semanticsOrError.n3",
           f"{phochste_uri}skolem.n3",
         #   f"{phochste_uri}trace.n3",     # BAD SYNTAX
           f"{phochste_uri}uri.n3",
           f"{phochste_uri}uuid.n3",  
           "eye-log-examples.n3"              
           ]

# %%
g = Graph()

for source in sources:
    g += Graph().parse(source, format='n3')
    
g.print()
# Out:
# @prefix ns1: <http://www.w3.org/2000/10/swap/log#> .
# @prefix ns2: <urn:example:> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# {_:_:Formula3175} ns1:implies {_:_:Formula3178} .
#
# {_:_:Formula3179} ns1:implies {_:_:Formula3180} .
#
# {_:_:Formula3182} ns1:implies {_:_:Formula3183} .
#
# {_:_:Formula3184} ns1:implies {_:_:Formula3185} .
#
# {_:_:Formula3187} ns1:implies {_:_:Formula3191} .
#
# {_:_:Formula3192} ns1:implies {_:_:Formula3193} .
#
# {_:_:Formula3198} ns1:implies {_:_:Formula3199} .
#
# {_:_:Formula3201} ns1:implies {_:_:Formula3202} .
#
# {_:_:Formula3204} ns1:implies {_:_:Formula3207} .
#
# {_:_:Formula3208} ns1:implies {_:_:Formula3210} .
#
# {_:_:Formula3212} ns1:implies {_:_:Formula3213} .
#
# {_:_:Formula3214} ns1:implies {_:_:Formula3215} .
#
# {_:_:Formula3217} ns1:implies {_:_:Formula3218} .
#
# ...
