# %%
from rdflib import Graph, URIRef

# %%
w3c_uri ='https://github.com/w3c/N3/raw/master/tests/N3Tests/cwm_list/'
phochste_uri = 'https://raw.githubusercontent.com/phochste/Notation3-By-Example/main/math/'

sources = [
            f"{phochste_uri}absoluteValue.n3",
            f"{phochste_uri}acos.n3",
            f"{phochste_uri}acosh.n3",
            f"{phochste_uri}asin.n3",
            f"{phochste_uri}atan.n3",
            f"{phochste_uri}ceiling.n3",
            f"{phochste_uri}cos.n3",
            f"{phochste_uri}cosh.n3",
            f"{phochste_uri}degrees.n3",
            f"{phochste_uri}difference.n3",
            f"{phochste_uri}equalTo.n3",
            f"{phochste_uri}exponentiation.n3",
            f"{phochste_uri}floor.n3",
            f"{phochste_uri}greaterThan.n3",
            f"{phochste_uri}lessThan.n3",
            f"{phochste_uri}logarithm.n3",
            f"{phochste_uri}max.n3",
            f"{phochste_uri}min.n3",
            f"{phochste_uri}negation.n3",
            f"{phochste_uri}notEqualTo.n3",
            f"{phochste_uri}notGreaterThan.n3",
            f"{phochste_uri}notLessThan.n3",
            f"{phochste_uri}product.n3",
            f"{phochste_uri}quotient.n3",
            f"{phochste_uri}radians.n3",
            f"{phochste_uri}remainder.n3",
            f"{phochste_uri}rounded.n3",
            f"{phochste_uri}roundedTo.n3",
            f"{phochste_uri}sin.n3",
            f"{phochste_uri}sinh.n3",
            f"{phochste_uri}sum.n3",
            f"{phochste_uri}tan.n3",
            f"{phochste_uri}tanh.n3",
           "eye-math-examples.n3"              
           ]

# %%
g = Graph()

for source in sources:
    g += Graph().parse(source, format='n3')
    
g.print()
# Out:
# @prefix ns1: <http://www.w3.org/2000/10/swap/log#> .
# @prefix ns2: <urn:example:> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# {_:_:Formula102} ns1:implies {_:_:Formula103} .
#
# {_:_:Formula104} ns1:implies {_:_:Formula105} .
#
# {_:_:Formula107} ns1:implies {_:_:Formula108} .
#
# {_:_:Formula109} ns1:implies {_:_:Formula110} .
#
# {_:_:Formula112} ns1:implies {_:_:Formula113} .
#
# {_:_:Formula114} ns1:implies {_:_:Formula115} .
#
# {_:_:Formula119} ns1:implies {_:_:Formula120} .
#
# {_:_:Formula12} ns1:implies {_:_:Formula13} .
#
# {_:_:Formula122} ns1:implies {_:_:Formula123} .
#
# {_:_:Formula124} ns1:implies {_:_:Formula125} .
#
# {_:_:Formula127} ns1:implies {_:_:Formula128} .
#
# {_:_:Formula129} ns1:implies {_:_:Formula130} .
#
# {_:_:Formula134} ns1:implies {_:_:Formula135} .
#
# {_:_:Formula137} ns1:implies {_:_:Formula138} .
#
# {_:_:Formula139} ns1:implies {_:_:Formula140} .
#
# ...
